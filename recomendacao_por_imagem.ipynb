# %%
#hide
# %%writefile kaggle.json
{"username":"<your kaggle username>","key":"<your kaggle api key>"}
# Out:
# Writing kaggle.json

# %%
#hide
# !pip install -q -U kaggle
# !pip install --upgrade --force-reinstall --no-deps kaggle
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# ...
#   Using cached kaggle-1.6.17-py3-none-any.whl
# ...
#   Attempting uninstall: kaggle
#     Found existing installation: kaggle 1.6.17
#     Uninstalling kaggle-1.6.17:
#       Successfully uninstalled kaggle-1.6.17
# ...
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
#hide-output
# downloading raw images from kaggle
# !kaggle datasets download -d paramaggarwal/fashion-product-images-small
# !unzip fashion-product-images-small.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: myntradataset/images/5813.jpg
#   inflating: myntradataset/images/58131.jpg
#   inflating: myntradataset/images/58132.jpg
#   inflating: myntradataset/images/58133.jpg
#   inflating: myntradataset/images/58135.jpg
#   inflating: myntradataset/images/58136.jpg
#   inflating: myntradataset/images/58137.jpg
#   inflating: myntradataset/images/58138.jpg
#   inflating: myntradataset/images/58139.jpg
#   inflating: myntradataset/images/5814.jpg
#   inflating: myntradataset/images/58140.jpg
#   inflating: myntradataset/images/58141.jpg
#   inflating: myntradataset/images/58143.jpg
#   inflating: myntradataset/images/58144.jpg
#   inflating: myntradataset/images/58145.jpg
#   inflating: myntradataset/images/58146.jpg
#   inflating: myntradataset/images/58147.jpg
#   inflating: myntradataset/images/58148.jpg
#   inflating: myntradataset/images/58149.jpg
#   inflating: myntradataset/images/5815.jpg
# ...

# %%
import os

# Criar uma pasta chamada "minha_pasta" dentro do diretório atual
os.makedirs("data", exist_ok=True)

# Verificar se a pasta foi criada
os.listdir(".")
# Out:
# ['.config', 'data', '.ipynb_checkpoints', 'sample_data']

# %%
# %cd /content
# Out:
# /content

# %%
from google.colab import files

# Selecionar arquivos do computador e fazer upload
uploaded = files.upload()

# Mover os arquivos para a pasta criada
import shutil
for filename in uploaded.keys():
    shutil.move(filename, "data/")
# Out:
#      <input type="file" id="files-d6d77c87-536e-4c48-a861-213a6a6a8473" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d6d77c87-536e-4c48-a861-213a6a6a8473">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# %cd /content/data
# Out:
# /content/data

# %%
# Criar uma pasta chamada "minha_pasta" dentro do diretório atual
os.makedirs("roupas", exist_ok=True)
os.makedirs("calcados", exist_ok=True)

# Verificar se a pasta foi criada
os.listdir(".")
# Out:
# ['calcados', 'fashion.csv', 'roupas']

# %%
# %cd /content/data/roupas
# Out:
# /content/data/roupas

# %%
os.makedirs("masculino", exist_ok=True)
os.makedirs("feminino", exist_ok=True)

# Verificar se a pasta foi criada
os.listdir(".")
# Out:
# ['feminino', 'masculino']

# %%
# %cd /content/data/roupas/masculino
# Out:
# /content/data/roupas/masculino

# %%
os.makedirs("Images", exist_ok=True)

# %%
# %cd /content/data/roupas/masculino/Images
# Out:
# /content/data/roupas/masculino/Images

# %%
os.makedirs("images_with_product_id", exist_ok=True)

# %%
# %cd /content/data/roupas/masculino/Images/images_with_product_id
# Out:
# /content/data/roupas/masculino/Images/images_with_product_id

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-806a4d83-2fad-4061-8f67-a593fb88156b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-806a4d83-2fad-4061-8f67-a593fb88156b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# %cd /content/data/roupas/feminino
# Out:
# /content/data/roupas/feminino

# %%
os.makedirs("Images", exist_ok=True)

# %%
# %cd /content/data/roupas/feminino/Images
# Out:
# /content/data/roupas/feminino/Images

# %%
os.makedirs("images_with_product_id", exist_ok=True)

# %%
# %cd /content/data/roupas/feminino/Images/images_with_product_id
# Out:
# /content/data/roupas/feminino/Images/images_with_product_id

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-26322315-7815-4196-be8f-3d401f6c3d05" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-26322315-7815-4196-be8f-3d401f6c3d05">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# %cd /content/data/calcados/
# Out:
# /content/data/calcados

# %%
os.makedirs("masculino", exist_ok=True)
os.makedirs("feminino", exist_ok=True)

# Verificar se a pasta foi criada
os.listdir(".")
# Out:
# ['feminino', 'masculino']

# %%
# %cd /content/data/calcados/masculino
# Out:
# /content/data/calcados/masculino

# %%
os.makedirs("Images", exist_ok=True)

# %%
# %cd /content/data/calcados/masculino/Images/
# Out:
# /content/data/calcados/masculino/Images

# %%
os.makedirs("images_with_product_id", exist_ok=True)

# %%
# %cd /content/data/calcados/masculino/Images/images_with_product_id/
# Out:
# /content/data/calcados/masculino/Images/images_with_product_id

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-610edb83-be9c-485c-97ba-d29f7eb4b563" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-610edb83-be9c-485c-97ba-d29f7eb4b563">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# %cd /content/data/calcados/feminino
# Out:
# /content/data/calcados/feminino

# %%
os.makedirs("Images", exist_ok=True)

# %%
# %cd /content/data/calcados/feminino/Images/
# Out:
# /content/data/calcados/feminino/Images

# %%
os.makedirs("images_with_product_id", exist_ok=True)

# %%
# %cd /content/data/calcados/feminino/Images/images_with_product_id/
# Out:
# /content/data/calcados/feminino/Images/images_with_product_id

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-95472123-f00b-4711-a582-474f7b9bb2e0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-95472123-f00b-4711-a582-474f7b9bb2e0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dropout, Flatten, Dense
from keras import applications
from sklearn.metrics import pairwise_distances
import requests
from PIL import Image
import pickle
from datetime import datetime
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
import plotly.figure_factory as ff
import plotly.graph_objects as go
import plotly.express as px
#import streamlit as st
#use the below library while displaying the images in jupyter notebook
from IPython.display import display, Image

fashion_df = pd.read_csv("/content/data/fashion.csv")

# %%
img_width, img_height = 224, 224

#top_model_weights_path = 'resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5'
train_data_dir = "/content/data/calcados/masculino/Images/"

nb_train_samples = 811
epochs = 50
batch_size = 1

def extract_features():
    Itemcodes = []
    datagen = ImageDataGenerator(rescale=1. / 255)
    model = applications.ResNet50(include_top=False, weights='imagenet')
    generator = datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        class_mode=None,
        shuffle=False)
    for i in generator.filenames:
        Itemcodes.append(i[(i.find("/")+1):i.find(".")])
    extracted_features = model.predict(generator, nb_train_samples // batch_size)
    extracted_features = extracted_features.reshape((811, 100352))

    np.save(open('./Men_ResNet_features.npy', 'wb'), extracted_features)
    np.save(open('./Men_ResNet_feature_product_ids.npy', 'wb'), np.array(Itemcodes))

a = datetime.now()
extract_features()
print("Time taken in feature extraction", datetime.now()-a)
# Out:
# ...
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Found 811 images belonging to 1 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 811/811 ━━━━━━━━━━━━━━━━━━━━ 182s 221ms/step
# Time taken in feature extraction 0:03:06.790469

# %%
import os
print(os.listdir("./"))
# Out:
# ['.config', 'kaggle.json', 'images', 'fashion-product-images-small.zip', 'myntradataset', 'data', 'styles.csv', '.ipynb_checkpoints', 'sample_data']

# %%
extracted_features = np.load('/content/working/Men_ResNet_features.npy')
Productids = np.load('/content/working/Men_ResNet_feature_product_ids.npy')
men = footwear_men.copy()
#men = pd.read_csv('./footwear_men.csv')
df_Productids = list(men['ProductId'])
Productids = list(Productids)

# %%
img_width, img_height = 224, 224


#top_model_weights_path = 'resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5'
train_data_dir = "/content/data/calcados/feminino/Images/"

nb_train_samples = 769
epochs = 50
batch_size = 1

def extract_features():
    Itemcodes = []
    datagen = ImageDataGenerator(rescale=1. / 255)
    model = applications.ResNet50(include_top=False, weights='imagenet')
    generator = datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        class_mode=None,
        shuffle=False)
    for i in generator.filenames:
        Itemcodes.append(i[(i.find("/")+1):i.find(".")])
    extracted_features = model.predict(generator, nb_train_samples // batch_size)
    extracted_features = extracted_features.reshape((769, 100352))

    np.save(open('/content/working/Women_ResNet_features.npy', 'wb'), extracted_features)
    np.save(open('/content/working/Women_ResNet_feature_product_ids.npy', 'wb'), np.array(Itemcodes))

a = datetime.now()
extract_features()
print("Time taken in feature extraction", datetime.now()-a)
# Out:
# Found 769 images belonging to 1 classes.
# 769/769 ━━━━━━━━━━━━━━━━━━━━ 176s 226ms/step
# Time taken in feature extraction 0:03:00.526705

# %%
img_width, img_height = 224, 224


#top_model_weights_path = 'resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5'
train_data_dir = "/content/data/roupas/masculino/Images"

nb_train_samples = 759
epochs = 50
batch_size = 1

def extract_features():
    Itemcodes = []
    datagen = ImageDataGenerator(rescale=1. / 255)
    model = applications.ResNet50(include_top=False, weights='imagenet')
    generator = datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        class_mode=None,
        shuffle=False)
    for i in generator.filenames:
        Itemcodes.append(i[(i.find("/")+1):i.find(".")])
    extracted_features = model.predict(generator, nb_train_samples // batch_size)
    extracted_features = extracted_features.reshape((759, 100352))

    np.save(open('/content/working/Boys_ResNet_features.npy', 'wb'), extracted_features)
    np.save(open('/content/working/Boys_ResNet_feature_product_ids.npy', 'wb'), np.array(Itemcodes))

a = datetime.now()
extract_features()
print("Time taken in feature extraction", datetime.now()-a)
# Out:
# Found 759 images belonging to 1 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 759/759 ━━━━━━━━━━━━━━━━━━━━ 178s 231ms/step
# Time taken in feature extraction 0:03:30.194195

# %%
img_width, img_height = 224, 224


#top_model_weights_path = 'resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5'
train_data_dir = "/content/data/roupas/feminino/Images"

nb_train_samples = 567
epochs = 50
batch_size = 1

def extract_features():
    Itemcodes = []
    datagen = ImageDataGenerator(rescale=1. / 255)
    model = applications.ResNet50(include_top=False, weights='imagenet')
    generator = datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        class_mode=None,
        shuffle=False)
    for i in generator.filenames:
        Itemcodes.append(i[(i.find("/")+1):i.find(".")])
    extracted_features = model.predict(generator, nb_train_samples // batch_size)
    extracted_features = extracted_features.reshape((567, 100352))

    np.save(open('/content/working/Girls_ResNet_features.npy', 'wb'), extracted_features)
    np.save(open('/content/working/Girls_ResNet_feature_product_ids.npy', 'wb'), np.array(Itemcodes))

a = datetime.now()
extract_features()
print("Time taken in feature extraction", datetime.now()-a)
# Out:
# Found 567 images belonging to 1 classes.
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 133s 232ms/step
# Time taken in feature extraction 0:02:16.800095

# %%
boys_extracted_features = np.load('/content/working/Boys_ResNet_features.npy')
boys_Productids = np.load('/content/working/Boys_ResNet_feature_product_ids.npy')
girls_extracted_features = np.load('/content/working/Girls_ResNet_features.npy')
girls_Productids = np.load('/content/working/Girls_ResNet_feature_product_ids.npy')
men_extracted_features = np.load('/content/working/Men_ResNet_features.npy')
men_Productids = np.load('/content/working/Men_ResNet_feature_product_ids.npy')
women_extracted_features = np.load('/content/working/Women_ResNet_features.npy')
women_Productids = np.load('/content/working/Women_ResNet_feature_product_ids.npy')
fashion_df["ProductId"] = fashion_df["ProductId"].astype(str)

# %%
def get_similar_products_cnn(product_id, num_results):
    if(fashion_df[fashion_df['ProductId']==product_id]['Gender'].values[0]=="Boys"):
        extracted_features = boys_extracted_features
        Productids = boys_Productids
    elif(fashion_df[fashion_df['ProductId']==product_id]['Gender'].values[0]=="Girls"):
        extracted_features = girls_extracted_features
        Productids = girls_Productids
    elif(fashion_df[fashion_df['ProductId']==product_id]['Gender'].values[0]=="Men"):
        extracted_features = men_extracted_features
        Productids = men_Productids
    elif(fashion_df[fashion_df['ProductId']==product_id]['Gender'].values[0]=="Women"):
        extracted_features = women_extracted_features
        Productids = women_Productids
    Productids = list(Productids)
    doc_id = Productids.index(product_id)
    pairwise_dist = pairwise_distances(extracted_features, extracted_features[doc_id].reshape(1,-1))
    indices = np.argsort(pairwise_dist.flatten())[0:num_results]
    pdists  = np.sort(pairwise_dist.flatten())[0:num_results]
    print("="*20, "input product details", "="*20)
    ip_row = fashion_df[['ImageURL','ProductTitle']].loc[fashion_df['ProductId']==Productids[indices[0]]]
    for indx, row in ip_row.iterrows():
        display(Image(url=row['ImageURL'], width = 224, height = 224,embed=True))
        print('Product Title: ', row['ProductTitle'])
    print("\n","="*20, "Recommended products", "="*20)
    for i in range(1,len(indices)):
        rows = fashion_df[['ImageURL','ProductTitle']].loc[fashion_df['ProductId']==Productids[indices[i]]]
        for indx, row in rows.iterrows():
            display(Image(url=row['ImageURL'], width = 224, height = 224,embed=True))
            print('Product Title: ', row['ProductTitle'])
            print('Euclidean Distance from input image:', pdists[i])

# %%
get_similar_products_cnn('10671', 5)
# Out:
# ==================== input product details ====================
# Product Title:  Doodle Boy Army  Green Shorts
#
#  ==================== Recommended products ====================
# Product Title:  Gini and Jony Boys Washed Blue 3/4 Length Pants
# Euclidean Distance from input image: 29.334776
# Product Title:  Gini and Jony Boys Washed Blue 3/4 Length Pants
# Euclidean Distance from input image: 29.334776
# Product Title:  Gini and Jony Boys Washed Blue 3/4 Length Pants
# Euclidean Distance from input image: 29.334776
# Product Title:  Palm Tree Boys Washed Blue 3/4 Length Pants
# Euclidean Distance from input image: 32.228195
